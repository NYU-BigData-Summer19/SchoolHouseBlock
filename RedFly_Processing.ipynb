# %%
import numpy as np
import pandas as pd

# %%
file = 'combined.csv'

df = pd.read_csv(file)

# %%
df.shape
# Out:
# (12222, 27)

# %%
for col in df.columns:
    print(col)
# Out:
# SALE TYPE
# SOLD DATE
# PROPERTY TYPE
# ADDRESS
# CITY
# STATE OR PROVINCE
# ZIP OR POSTAL CODE
# PRICE
# BEDS
# BATHS
# LOCATION
# SQUARE FEET
# LOT SIZE
# YEAR BUILT
# DAYS ON MARKET
# $/SQUARE FEET
# HOA/MONTH
# STATUS
# NEXT OPEN HOUSE START TIME
# NEXT OPEN HOUSE END TIME
# URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)
# SOURCE
# MLS#
# FAVORITE
# INTERESTED
# LATITUDE
# LONGITUDE

# %%
df.head()
# Out:
#      SALE TYPE SOLD DATE              PROPERTY TYPE                ADDRESS  \
# 0  MLS Listing       NaN  Single Family Residential   7088 Shadow Ridge Ct
# 1  MLS Listing       NaN                Vacant Land  5445 Sanctuary Pl #25
# 2  MLS Listing       NaN  Single Family Residential        4706 Sanibel Ln
# 3  MLS Listing       NaN  Single Family Residential        205 Michael Ave
# 4  MLS Listing       NaN                  Townhouse      9477 Colegate Way
#
#            CITY STATE OR PROVINCE ZIP OR POSTAL CODE   PRICE BEDS BATHS  ...  \
# 0   Liberty Twp                OH              45011  458000    4   4.5  ...
# 1   Liberty Twp                OH              45011  115000  NaN   NaN  ...
# 2   Liberty Twp                OH              45011  379900    3   2.5  ...
# 3      Hamilton                OH              45011  106000    3   1.0  ...
# 4  West Chester                OH              45011  129900    2   3.0  ...
#
# ...
